# %%
API_KEY = 'AIzaSyDR39_JwciKu-aydqDzI92TTjQh7DJ6ZhI'

# %%
import os
from googleapiclient.discovery import build

youtube = build('youtube', 'v3', developerKey=API_KEY)

def get_trending_videos(region_code='UA'):
    request = youtube.videos().list(
        part="snippet",
        chart="mostPopular",
        regionCode=region_code,
        maxResults=100
    )
    response = request.execute()
    return response.get('items', [])

def get_channel_videos(channel_id):
    videos = []
    next_page_token = None

    while True:
        response = youtube.search().list(
            channelId=channel_id,
            part='snippet',
            order='date',
            maxResults=200,
            pageToken=next_page_token
        ).execute()

        for v in response['items']:
            videos.append(v)
    
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break
    return videos

def check_videos_for_keyword(videos, keyword):
    matching_videos = []
    for video in videos:
        title = video['snippet']['title']
        description = video['snippet']['description']
        if keyword.lower() in title.lower() or keyword.lower() in description.lower():
            matching_videos.append(video)
    return matching_videos

def main(get_videos, args, keyword):
    video_info = get_videos(args)
    for i in video_info: print(i['snippet']['title'])
    matching_videos = check_videos_for_keyword(video_info, keyword)
    
    print(f"\nFound {len(matching_videos)} videos with the keyword '{keyword}':\n")
    for video in matching_videos:
        title = video['snippet']['title']
        date = video['snippet']['publishedAt']
        video_id = video['id']
        url = f"https://www.youtube.com/watch?v={video_id}"
        print(f"Title: {title}\nURL: {url}\nDate: {date}\n")

# %%
main(get_trending_videos, 'UA', 'війна')
# Out:
# Sprinting with More and More Money
# У Дніпрі чоловік, якого силоміць везли на мобілізацію, втік з буса ТЦК #війна #мобілізації
# ТЦК санаторій "Сонячне Закарпаття" люди вийшли
# ✈️ ЗСУ відтісняють авіацію РФ за полярне коло
# Железная задница #орехов #типичный #мотоциклист #байкер
# $10,000 Every Day You Survive In The Wilderness
# ВІТАЛІЙ ВОЛОЧАЙ В КЛУБІ ДИЛЕТАНТІВ 37
# The GIRL's skills are AMAZING🔪🎋#camping #survival #bushcraft #outdoors #lifehack
# Сын провинился 😱 #ComedyClub #КамедиКлаб #батрутдинов #харламов #тнт4 #гарикхарламов #тнт #депутат
# The Worlds Most Powerfull Batteries !
# 😱РОСІЯНИ СТРАШЕННО НАЛЯКАНІ РАКЕТАМИ Tomahawk зі США #shorts #росіяни  #tomahawk
# Заметили?
# Батальйон Монако, ТЦК ви де?
# ⚡"ЦЕ НЕПРИКРИТА БРЕХНЯ!"💥Лана ЗЕРКАЛЬ і підвищення тарифів на електроенергію. Де правда? Яніна знає!
# ЛЕБІГА, МАЙОРОВА, КУХАРЧУК, ТКАЧЕНКО. РОЗРЯД | ВИПУСК 13
# 💔 Історія захисника Маріуполя, який втратив ногу, осліп на праве око і пройшов полон. #зсу #shorts
# ...

# %%
main(get_channel_videos, 'UC7AvvBtzbwWpkcwxV4bGKLw', 'гори')
# Out:
# Найдивніший мегаполіс світу та як ЯПОНІЯ стала такою, як вона є.
# Зимова ЯПОНІЯ. Культурні відкриття, острів, який ледь не став СРСР та найкращий у світі сніг.
# Більш детальний тест- драйв невдовзі на каналі @TERENUA
# Не шукайте цей готель на букінгу чи еірбнб
# Найзимніший похід в Карпати, в який ви не підете. Від Слона до Слона.
# Маленький драгобратський гілті плежур
# Головний монстр Драгобрату
# Одна з найяскравіших різдвяних подій України
# Маленька пригода у Великих Карпатах.
# Сніги вже у Карпатах, тому нагадую вам про важливість гірськолижного захисту
# Велика Британія
# ШОТЛАНДІЯ. Суворе, але фантастичне Високогір&#39;я.
# Що б з цієї трійці найтрадиційніших шотландських смаколиків ви спробували? #шотландія #їжа
# Звідки насправді пішли імена персонажів з Гаррі Поттера #шотландія
# Свобода, кілти, їжа з тельбухів та створення GTA 6. ШОТЛАНДІЯ та чим вона близька Україні.
# Лондонський офіс-санаторій Google
# ...
